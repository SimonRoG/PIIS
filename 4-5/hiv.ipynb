# %%
from openai import OpenAI
import json

with open("keys.json") as f:
    keys = json.load(f)

client = OpenAI(api_key=keys["openai_api"])

response = client.responses.create(model="gpt-5-nano", input="назви симптоми ВІЛ")

print(response.output_text)
# Out:
# Ось основні симптоми, але вони часто неспецифічні й з’являються також при інших захворюваннях. Найнадійніший спосіб дізнатися, чи є ВІЛ, — тестування.
#
# - Гостра ВІЛ-інфекція (перші тижні після зараження)
#   - лихоманка
#   - висипка
#   - біль у горлі
#   - збільшені лімфатичні вузли
#   - сильна втома
#   - головний біль
#   - м’язово‑суглобний біль
#   - піт ночами
#   - нудота/діарея
#   - виразки у роті
#
# - Безсимптомна (латентна) стадія
#   - часто без помітних симптомів протягом місяців–років
#
# - Симптоматична ВІЛ-інфекція (пізня стадія до СІД)
#   - повторювані лихоманки та нічна пітливість
#   - сильна втома
#   - втрата ваги
#   - діарея, що триває довго
#   - збільшені лімфатичні вузли
#   - повторювані інфекції ротa, шкіри, піхви
#   - молочниця в роті/горлі, кандидоз
#   - шкірні висипи, герпетичні або опортуністичні інфекції
#
# - СІД (у випадку тяжкого імунного виснаження)
#   - тяжкі, повторювані інфекції та інфекції легень, мозку, інші
# ...
